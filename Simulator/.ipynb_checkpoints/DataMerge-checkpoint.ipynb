# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import time
import requests
from datetime import datetime, timedelta
from shapely.geometry import Point
from busSim import BusSim
from graph import Graph

# %%
blocks = gpd. read_file("zip://DataMerge/dane_blocks_shapes.zip")
blocks = blocks.to_crs("EPSG:4326")

# %%
blocks
# Out:
#     STATEFP10 COUNTYFP10 TRACTCE10  ...   INTPTLAT10    INTPTLON10                                           geometry
# 0          55        025    011504  ...  +43.1906083  -089.2482047  POLYGON ((-89.25928 43.18706, -89.25991 43.187...
# 1          55        025    012501  ...  +42.9077310  -089.3807759  POLYGON ((-89.37390 42.91633, -89.37390 42.916...
# 2          55        025    001403  ...  +43.0211647  -089.4410349  POLYGON ((-89.44960 43.02226, -89.44958 43.022...
# 3          55        025    013301  ...  +43.2478834  -089.3162326  POLYGON ((-89.34136 43.25267, -89.34141 43.253...
# 4          55        025    013301  ...  +43.2356950  -089.3326201  POLYGON ((-89.33398 43.24769, -89.33167 43.247...
# ..        ...        ...       ...  ...          ...           ...                                                ...
# 305        55        025    011102  ...  +43.1140710  -089.4801041  POLYGON ((-89.49144 43.11327, -89.49143 43.114...
# 306        55        025    011102  ...  +43.1263555  -089.4965035  POLYGON ((-89.50137 43.11301, -89.50137 43.113...
# 307        55        025    011102  ...  +43.1068366  -089.4780431  POLYGON ((-89.47114 43.11042, -89.47154 43.110...
# 308        55        025    012001  ...  +43.0988322  -089.2184686  POLYGON ((-89.24675 43.10702, -89.24676 43.107...
# 309        55        025    011504  ...  +43.1794745  -089.2543204  POLYGON ((-89.25947 43.16790, -89.25977 43.167...
#
# [310 rows x 13 columns]

# %%
madison= gpd.read_file("zip://DataMerge/city_Limit.zip")
madison= madison.to_crs("EPSG:4326")
mdf=gpd.sjoin(blocks, madison)
mdf=mdf[["GEOID10","geometry"]]

# %%
mdf
# Out:
#           GEOID10                                           geometry
# 2    550250014031  POLYGON ((-89.44960 43.02226, -89.44958 43.022...
# 7    550250020003  POLYGON ((-89.33433 43.08995, -89.33429 43.089...
# 8    550250021002  POLYGON ((-89.34428 43.10322, -89.34435 43.103...
# 9    550250021004  POLYGON ((-89.36409 43.09863, -89.36409 43.098...
# 10   550250021003  POLYGON ((-89.34989 43.10227, -89.34978 43.102...
# ..            ...                                                ...
# 36   550250105021  POLYGON ((-89.27644 43.02638, -89.27629 43.026...
# 77   550250102001  POLYGON ((-89.36699 43.09883, -89.36731 43.098...
# 270  550250018042  POLYGON ((-89.36408 43.09883, -89.36409 43.098...
# 277  550259917020  POLYGON ((-89.41319 43.14705, -89.41301 43.147...
# 84   550250114021  POLYGON ((-89.24686 43.12177, -89.24686 43.121...
#
# [200 rows x 2 columns]

# %%
ax = mdf.boundary.plot(color="black",linewidth=0.2, figsize=(12,12))
ax.set_axis_off()

# %%
mdf.GEOID10
# Out:
# 2      550250014031
# 7      550250020003
# 8      550250021002
# 9      550250021004
# 10     550250021003
#            ...
# 36     550250105021
# 77     550250102001
# 270    550250018042
# 277    550259917020
# 84     550250114021
# Name: GEOID10, Length: 200, dtype: object

# %%
df = pd.read_csv("DataMerge/education.csv")
df = df[1:]
for idx, row in df.iterrows():
    row.GEO_ID = row.GEO_ID.split("US")[1]

# %%
cdf = pd.merge(mdf,df,left_on="GEOID10",right_on="GEO_ID",how="left")

# %%
cdf
# Out:
#     STATEFP10 COUNTYFP10 TRACTCE10 BLKGRPCE10       GEOID10  ... B14007_017M B14007_018E B14007_018M  B14007_019E  B14007_019M
# 0          55        025    001403          1  550250014031  ...          81         112          60         2059          264
# 1          55        025    002000          3  550250020003  ...          52         155          83         1097          179
# 2          55        025    002100          2  550250021002  ...          55          12          19          884          190
# 3          55        025    002100          4  550250021004  ...          54          76          49          764          172
# 4          55        025    002100          3  550250021003  ...          51          64          49          701          201
# ..        ...        ...       ...        ...           ...  ...         ...         ...         ...          ...          ...
# 195        55        025    010502          1  550250105021  ...          44          34          40         1155          261
# 196        55        025    010200          1  550250102001  ...          16          19          13         1024           58
# 197        55        025    001804          2  550250018042  ...         148         117          51         1541          220
# 198        55        025    991702          0  550259917020  ...           9           0           9            0            9
# 199        55        025    011402          1  550250114021  ...          69         120          97         1650          235
#
# [200 rows x 57 columns]
